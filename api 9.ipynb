# %% [markdown]
# import necessary libraries

# %%
import requests
import pandas as pd
import json

# %% [markdown]
# assign api to variable

# %%
url = "http://api.tvmaze.com/search/shows?q=golden girls"

# %% [markdown]
# check error response for api

# %%
data = requests.get(url).json()

# %%
data
# Out:
# [{'score': 1.1891892,
#   'show': {'id': 5451,
#    'url': 'https://www.tvmaze.com/shows/5451/golden-girls',
#    'name': 'Golden Girls',
#    'type': 'Scripted',
#    'language': 'Dutch',
#    'genres': ['Comedy', 'Family', 'Romance'],
#    'status': 'Ended',
#    'runtime': 30,
#    'averageRuntime': 30,
#    'premiered': '2012-08-25',
#    'ended': '2012-11-03',
#    'officialSite': None,
#    'schedule': {'time': '20:00', 'days': ['Saturday']},
#    'rating': {'average': None},
#    'weight': 75,
#    'network': {'id': 112,
#     'name': 'RTL4',
#     'country': {'name': 'Netherlands',
#      'code': 'NL',
#      'timezone': 'Europe/Amsterdam'},
#     'officialSite': None},
#    'webChannel': None,
#    'dvdCountry': None,
#    'externals': {'tvrage': None, 'thetvdb': 262042, 'imdb': 'tt2359096'},
#    'image': {'medium': 'https://static.tvmaze.com/uploads/images/medium_portrait/22/55709.jpg',
# ...

# %%
data=pd.DataFrame(data)
data
# Out:
#       score  show.id                                           show.url  \
# 0  1.189189     5451     https://www.tvmaze.com/shows/5451/golden-girls
# 1  1.017159      722  https://www.tvmaze.com/shows/722/the-golden-girls
# 2  0.516625    57291  https://www.tvmaze.com/shows/57291/the-holden-...
#
#                           show.name show.type show.language  \
# 0                      Golden Girls  Scripted         Dutch
# 1                  The Golden Girls  Scripted       English
# 2  The Holden Girls: Mandy & Myrtle  Scripted       English
#
#                  show.genres show.status  show.runtime  show.averageRuntime  \
# 0  [Comedy, Family, Romance]       Ended          30.0                   30
# 1            [Drama, Comedy]       Ended          30.0                   30
# 2                   [Comedy]     Running           NaN                   32
#
#    ... show.dvdCountry show.externals.tvrage show.externals.thetvdb  \
# ...

# %%
data.explode("show.genres", ignore_index = True)
# Out:
#       score  show.id                                           show.url  \
# 0  1.189189     5451     https://www.tvmaze.com/shows/5451/golden-girls
# 1  1.189189     5451     https://www.tvmaze.com/shows/5451/golden-girls
# 2  1.189189     5451     https://www.tvmaze.com/shows/5451/golden-girls
# 3  1.017159      722  https://www.tvmaze.com/shows/722/the-golden-girls
# 4  1.017159      722  https://www.tvmaze.com/shows/722/the-golden-girls
# 5  0.516625    57291  https://www.tvmaze.com/shows/57291/the-holden-...
#
#                           show.name show.type show.language show.genres  \
# 0                      Golden Girls  Scripted         Dutch      Comedy
# 1                      Golden Girls  Scripted         Dutch      Family
# 2                      Golden Girls  Scripted         Dutch     Romance
# 3                  The Golden Girls  Scripted       English       Drama
# 4                  The Golden Girls  Scripted       English      Comedy
# ...
