# %% [markdown]
# import necessary libraries

# %%
import requests
import pandas as pd
import json

# %% [markdown]
# assign api to variable

# %%
url = "https://api.coinpaprika.com/v1/coins/btc-bitcoin"

# %% [markdown]
# check error response for api

# %%
requests.get(url)
# Out:
# <Response [200]>

# %% [markdown]
# inspect data

# %% [markdown]
# assign result to a variable

# %%
data = requests.get(url).json()
data
# Out:
# {'id': 'btc-bitcoin',
#  'name': 'Bitcoin',
#  'symbol': 'BTC',
#  'rank': 1,
#  'is_new': False,
#  'is_active': True,
#  'type': 'coin',
#  'tags': [{'id': 'segwit',
#    'name': 'Segwit',
#    'coin_counter': 10,
#    'ico_counter': 0},
#   {'id': 'cryptocurrency',
#    'name': 'Cryptocurrency',
#    'coin_counter': 856,
#    'ico_counter': 40},
#   {'id': 'proof-of-work',
#    'name': 'Proof Of Work',
#    'coin_counter': 424,
#    'ico_counter': 14},
#   {'id': 'payments',
#    'name': 'Payments',
#    'coin_counter': 171,
#    'ico_counter': 39},
#   {'id': 'sha256', 'name': 'Sha256', 'coin_counter': 42, 'ico_counter': 1},
#   {'id': 'mining', 'name': 'Mining', 'coin_counter': 275, 'ico_counter': 18},
#   {'id': 'lightning-network',
#    'name': 'Lightning Network',
#    'coin_counter': 6,
#    'ico_counter': 0}],
#  'team': [{'id': 'satoshi-nakamoto',
#    'name': 'Satoshi Nakamoto',
#    'position': 'Founder'},
#   {'id': 'wladimir-j-van-der-laan',
#    'name': 'Wladimir J. van der Laan',
#    'position': 'Blockchain Developer'},
#   {'id': 'jonas-schnelli',
#    'name': 'Jonas Schnelli',
#    'position': 'Blockchain Developer'},
#   {'id': 'marco-falke',
#    'name': 'Marco Falke',
#    'position': 'Blockchain Developer'}],
#  'description': 'Bitcoin is a cryptocurrency and worldwide payment system. It is the first decentralized digital currency, as the system works without a central bank or single administrator.',
#  'message': '',
#  'open_source': True,
#  'started_at': '2009-01-03T00:00:00Z',
#  'development_status': 'Working product',
#  'hardware_wallet': True,
#  'proof_type': 'Proof of Work',
#  'org_structure': 'Decentralized',
#  'hash_algorithm': 'SHA256',
#  'links': {'explorer': ['https://blockchair.com/bitcoin',
#    'https://blockchain.com/explorer',
#    'https://blockstream.info/',
#    'https://live.blockcypher.com/btc/',
#    'https://btc.cryptoid.info/btc/'],
#   'facebook': ['https://www.facebook.com/bitcoins/'],
#   'reddit': ['https://www.reddit.com/r/bitcoin'],
#   'source_code': ['https://github.com/bitcoin/bitcoin'],
#   'website': ['https://bitcoin.org/'],
#   'youtube': ['https://www.youtube.com/watch?v=Gc2en3nHxA4&']},
#  'links_extended': [{'url': 'https://bitcoin.org/en/blog', 'type': 'blog'},
#   {'url': 'https://blockchair.com/bitcoin', 'type': 'explorer'},
#   {'url': 'https://blockchain.com/explorer', 'type': 'explorer'},
#   {'url': 'https://blockstream.info/', 'type': 'explorer'},
#   {'url': 'https://live.blockcypher.com/btc/', 'type': 'explorer'},
#   {'url': 'https://btc.cryptoid.info/btc/', 'type': 'explorer'},
#   {'url': 'https://www.facebook.com/bitcoins/', 'type': 'facebook'},
#   {'url': 'https://bitcointalk.org', 'type': 'message_board'},
#   {'url': 'https://www.reddit.com/r/bitcoin',
#    'type': 'reddit',
#    'stats': {'subscribers': 4408797}},
#   {'url': 'https://github.com/bitcoin/bitcoin',
#    'type': 'source_code',
#    'stats': {'contributors': 1082, 'stars': 65336}},
#   {'url': 'https://twitter.com/bitcoincoreorg',
#    'type': 'twitter',
#    'stats': {'followers': 159175}},
#   {'url': 'https://electrum.org/#download', 'type': 'wallet'},
#   {'url': 'https://bitcoin.org/', 'type': 'website'},
#   {'url': 'https://www.youtube.com/watch?v=Gc2en3nHxA4&', 'type': 'youtube'}],
#  'whitepaper': {'link': 'https://static.coinpaprika.com/storage/cdn/whitepapers/215.pdf',
#   'thumbnail': 'https://static.coinpaprika.com/storage/cdn/whitepapers/217.jpg'},
#  'first_data_at': '2010-07-17T00:00:00Z',
#  'last_data_at': '2022-07-20T04:25:00Z'}

# %% [markdown]
# normalizing the json using json_normalize

# %%
b=pd.json_normalize(data)
b
# Out:
#             id     name symbol  rank  is_new  is_active  type  \
# 0  btc-bitcoin  Bitcoin    BTC     1   False       True  coin
#
#                                                 tags  \
# 0  [{'id': 'segwit', 'name': 'Segwit', 'coin_coun...
#
#                                                 team  \
# 0  [{'id': 'satoshi-nakamoto', 'name': 'Satoshi N...
#
#                                          description  ...  \
# 0  Bitcoin is a cryptocurrency and worldwide paym...  ...
#
#           first_data_at          last_data_at  \
# 0  2010-07-17T00:00:00Z  2022-07-20T04:25:00Z
#
#                                       links.explorer  \
# 0  [https://blockchair.com/bitcoin, https://block...
#
#                          links.facebook                        links.reddit  \
# 0  [https://www.facebook.com/bitcoins/]  [https://www.reddit.com/r/bitcoin]
#
#                       links.source_code           links.website  \
# 0  [https://github.com/bitcoin/bitcoin]  [https://bitcoin.org/]
#
#                                     links.youtube  \
# 0  [https://www.youtube.com/watch?v=Gc2en3nHxA4&]
#
#                                      whitepaper.link  \
# 0  https://static.coinpaprika.com/storage/cdn/whi...
#
#                                 whitepaper.thumbnail
# 0  https://static.coinpaprika.com/storage/cdn/whi...
#
# [1 rows x 29 columns]

# %%
dict = {'id': 'iden', 'name': 'names'}
 
# call rename () method
b.rename(columns=dict,
          inplace=True)

# %%
tags = pd.json_normalize(data, 'tags', ['iden', 'names', 'symbol', 'rank', 'is_new', 'is_active', 'type', 'tags',
       'team', 'description', 'message', 'open_source', 'started_at',
       'development_status', 'hardware_wallet', 'proof_type', 'org_structure',
       'hash_algorithm', 'links_extended', 'first_data_at', 'last_data_at'], errors='ignore' )
team = json_normalize(data, 'team', ['iden'], errors='ignore' )

result = tags.merge(team, on='iden')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-854ecb37ac79> in <module>
# ----> 1 tags = pd.json_normalize(data, 'tags', ['iden', 'names', 'symbol', 'rank', 'is_new', 'is_active', 'type', 'tags',
#       2        'team', 'description', 'message', 'open_source', 'started_at',
#       3        'development_status', 'hardware_wallet', 'proof_type', 'org_structure',
#       4        'hash_algorithm', 'links_extended', 'first_data_at', 'last_data_at'], errors='ignore' )
#       5 team = json_normalize(data, 'team', ['iden'], errors='ignore' )
#
# ~\anaconda3\envs\test\lib\site-packages\pandas\io\json\_normalize.py in _json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     350                 f"Conflicting metadata name {k}, need distinguishing prefix "
#     351             )
# --> 352         result[k] = np.array(v, dtype=object).repeat(lengths)
#     353     return result
#     354
#
# ~\anaconda3\envs\test\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3038         else:
#    3039             # set column
# -> 3040             self._set_item(key, value)
#    3041
#    3042     def _setitem_slice(self, key: slice, value):
#
# ~\anaconda3\envs\test\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3114         """
#    3115         self._ensure_valid_index(value)
# -> 3116         value = self._sanitize_column(key, value)
#    3117         NDFrame._set_item(self, key, value)
#    3118
#
# ~\anaconda3\envs\test\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3762
#    3763             # turn me into an ndarray
# -> 3764             value = sanitize_index(value, self.index)
#    3765             if not isinstance(value, (np.ndarray, Index)):
#    3766                 if isinstance(value, list) and len(value) > 0:
#
# ~\anaconda3\envs\test\lib\site-packages\pandas\core\internals\construction.py in sanitize_index(data, index)
#     745     """
#     746     if len(data) != len(index):
# --> 747         raise ValueError(
#     748             "Length of values "
#     749             f"({len(data)}) "
#
# ValueError: Length of values (49) does not match length of index (7)

# %% [markdown]
# after appying json_normalize there are still columns with list of dictionaries
# therefore I used the argument record_path to flatten the JSON further

# %%
#could not pass multiple column into record_path

pd.json_normalize(
    data, 
    record_path =[['tags', 'team']], 
    meta=['symbol']
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-f17d65e2c3c1> in <module>
#       1 #could not pass multiple column into record_path
#       2
# ----> 3 pd.json_normalize(
#       4     data,
#       5     record_path =(['tags', 'team']),
#
# ~\anaconda3\envs\test\lib\site-packages\pandas\io\json\_normalize.py in _json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     334                 records.extend(recs)
#     335
# --> 336     _recursive_extract(data, record_path, {}, level=0)
#     337
#     338     result = DataFrame(records)
#
# ~\anaconda3\envs\test\lib\site-packages\pandas\io\json\_normalize.py in _recursive_extract(data, path, seen_meta, level)
#     304                         seen_meta[key] = _pull_field(obj, val[-1])
#     305
# --> 306                 _recursive_extract(obj[path[0]], path[1:], seen_meta, level=level + 1)
#     307         else:
#     308             for obj in data:
#
# ~\anaconda3\envs\test\lib\site-packages\pandas\io\json\_normalize.py in _recursive_extract(data, path, seen_meta, level)
#     307         else:
#     308             for obj in data:
# --> 309                 recs = _pull_records(obj, path[0])
#     310                 recs = [
#     311                     nested_to_record(r, sep=sep, max_level=max_level)
#
# ~\anaconda3\envs\test\lib\site-packages\pandas\io\json\_normalize.py in _pull_records(js, spec)
#     246         if has non iterable value.
#     247         """
# --> 248         result = _pull_field(js, spec)
#     249
#     250         # GH 31507 GH 30145, GH 26284 if result is not list, raise TypeError if not
#
# ~\anaconda3\envs\test\lib\site-packages\pandas\io\json\_normalize.py in _pull_field(js, spec)
#     237                 result = result[field]
#     238         else:
# --> 239             result = result[spec]
#     240         return result
#     241
#
# KeyError: 'team'

# %%
b=b.explode("tags")
b=b.explode("team")

# %%
b=pd.json_normalize(json.loads(b.to_json(orient="records")))
b
# Out:
#              id     name symbol  rank  is_new  is_active  type  \
# 0   btc-bitcoin  Bitcoin    BTC     1   False       True  coin
# 1   btc-bitcoin  Bitcoin    BTC     1   False       True  coin
# 2   btc-bitcoin  Bitcoin    BTC     1   False       True  coin
# 3   btc-bitcoin  Bitcoin    BTC     1   False       True  coin
# 4   btc-bitcoin  Bitcoin    BTC     1   False       True  coin
# 5   btc-bitcoin  Bitcoin    BTC     1   False       True  coin
# 6   btc-bitcoin  Bitcoin    BTC     1   False       True  coin
# 7   btc-bitcoin  Bitcoin    BTC     1   False       True  coin
# 8   btc-bitcoin  Bitcoin    BTC     1   False       True  coin
# 9   btc-bitcoin  Bitcoin    BTC     1   False       True  coin
# 10  btc-bitcoin  Bitcoin    BTC     1   False       True  coin
# 11  btc-bitcoin  Bitcoin    BTC     1   False       True  coin
# 12  btc-bitcoin  Bitcoin    BTC     1   False       True  coin
# 13  btc-bitcoin  Bitcoin    BTC     1   False       True  coin
# 14  btc-bitcoin  Bitcoin    BTC     1   False       True  coin
# 15  btc-bitcoin  Bitcoin    BTC     1   False       True  coin
# 16  btc-bitcoin  Bitcoin    BTC     1   False       True  coin
# 17  btc-bitcoin  Bitcoin    BTC     1   False       True  coin
# 18  btc-bitcoin  Bitcoin    BTC     1   False       True  coin
# 19  btc-bitcoin  Bitcoin    BTC     1   False       True  coin
# 20  btc-bitcoin  Bitcoin    BTC     1   False       True  coin
# 21  btc-bitcoin  Bitcoin    BTC     1   False       True  coin
# 22  btc-bitcoin  Bitcoin    BTC     1   False       True  coin
# 23  btc-bitcoin  Bitcoin    BTC     1   False       True  coin
# 24  btc-bitcoin  Bitcoin    BTC     1   False       True  coin
# 25  btc-bitcoin  Bitcoin    BTC     1   False       True  coin
# 26  btc-bitcoin  Bitcoin    BTC     1   False       True  coin
# 27  btc-bitcoin  Bitcoin    BTC     1   False       True  coin
#
#                                           description message  open_source  \
# 0   Bitcoin is a cryptocurrency and worldwide paym...                 True
# 1   Bitcoin is a cryptocurrency and worldwide paym...                 True
# 2   Bitcoin is a cryptocurrency and worldwide paym...                 True
# 3   Bitcoin is a cryptocurrency and worldwide paym...                 True
# 4   Bitcoin is a cryptocurrency and worldwide paym...                 True
# 5   Bitcoin is a cryptocurrency and worldwide paym...                 True
# 6   Bitcoin is a cryptocurrency and worldwide paym...                 True
# 7   Bitcoin is a cryptocurrency and worldwide paym...                 True
# 8   Bitcoin is a cryptocurrency and worldwide paym...                 True
# 9   Bitcoin is a cryptocurrency and worldwide paym...                 True
# 10  Bitcoin is a cryptocurrency and worldwide paym...                 True
# 11  Bitcoin is a cryptocurrency and worldwide paym...                 True
# 12  Bitcoin is a cryptocurrency and worldwide paym...                 True
# 13  Bitcoin is a cryptocurrency and worldwide paym...                 True
# 14  Bitcoin is a cryptocurrency and worldwide paym...                 True
# 15  Bitcoin is a cryptocurrency and worldwide paym...                 True
# 16  Bitcoin is a cryptocurrency and worldwide paym...                 True
# 17  Bitcoin is a cryptocurrency and worldwide paym...                 True
# 18  Bitcoin is a cryptocurrency and worldwide paym...                 True
# 19  Bitcoin is a cryptocurrency and worldwide paym...                 True
# 20  Bitcoin is a cryptocurrency and worldwide paym...                 True
# 21  Bitcoin is a cryptocurrency and worldwide paym...                 True
# 22  Bitcoin is a cryptocurrency and worldwide paym...                 True
# 23  Bitcoin is a cryptocurrency and worldwide paym...                 True
# 24  Bitcoin is a cryptocurrency and worldwide paym...                 True
# 25  Bitcoin is a cryptocurrency and worldwide paym...                 True
# 26  Bitcoin is a cryptocurrency and worldwide paym...                 True
# 27  Bitcoin is a cryptocurrency and worldwide paym...                 True
#
#     ...                                   links.youtube  \
# 0   ...  [https://www.youtube.com/watch?v=Gc2en3nHxA4&]
# 1   ...  [https://www.youtube.com/watch?v=Gc2en3nHxA4&]
# 2   ...  [https://www.youtube.com/watch?v=Gc2en3nHxA4&]
# 3   ...  [https://www.youtube.com/watch?v=Gc2en3nHxA4&]
# 4   ...  [https://www.youtube.com/watch?v=Gc2en3nHxA4&]
# 5   ...  [https://www.youtube.com/watch?v=Gc2en3nHxA4&]
# 6   ...  [https://www.youtube.com/watch?v=Gc2en3nHxA4&]
# 7   ...  [https://www.youtube.com/watch?v=Gc2en3nHxA4&]
# 8   ...  [https://www.youtube.com/watch?v=Gc2en3nHxA4&]
# 9   ...  [https://www.youtube.com/watch?v=Gc2en3nHxA4&]
# 10  ...  [https://www.youtube.com/watch?v=Gc2en3nHxA4&]
# 11  ...  [https://www.youtube.com/watch?v=Gc2en3nHxA4&]
# 12  ...  [https://www.youtube.com/watch?v=Gc2en3nHxA4&]
# 13  ...  [https://www.youtube.com/watch?v=Gc2en3nHxA4&]
# 14  ...  [https://www.youtube.com/watch?v=Gc2en3nHxA4&]
# 15  ...  [https://www.youtube.com/watch?v=Gc2en3nHxA4&]
# 16  ...  [https://www.youtube.com/watch?v=Gc2en3nHxA4&]
# 17  ...  [https://www.youtube.com/watch?v=Gc2en3nHxA4&]
# 18  ...  [https://www.youtube.com/watch?v=Gc2en3nHxA4&]
# 19  ...  [https://www.youtube.com/watch?v=Gc2en3nHxA4&]
# 20  ...  [https://www.youtube.com/watch?v=Gc2en3nHxA4&]
# 21  ...  [https://www.youtube.com/watch?v=Gc2en3nHxA4&]
# 22  ...  [https://www.youtube.com/watch?v=Gc2en3nHxA4&]
# 23  ...  [https://www.youtube.com/watch?v=Gc2en3nHxA4&]
# 24  ...  [https://www.youtube.com/watch?v=Gc2en3nHxA4&]
# 25  ...  [https://www.youtube.com/watch?v=Gc2en3nHxA4&]
# 26  ...  [https://www.youtube.com/watch?v=Gc2en3nHxA4&]
# 27  ...  [https://www.youtube.com/watch?v=Gc2en3nHxA4&]
#
#                                       whitepaper.link  \
# 0   https://static.coinpaprika.com/storage/cdn/whi...
# 1   https://static.coinpaprika.com/storage/cdn/whi...
# 2   https://static.coinpaprika.com/storage/cdn/whi...
# 3   https://static.coinpaprika.com/storage/cdn/whi...
# 4   https://static.coinpaprika.com/storage/cdn/whi...
# 5   https://static.coinpaprika.com/storage/cdn/whi...
# 6   https://static.coinpaprika.com/storage/cdn/whi...
# 7   https://static.coinpaprika.com/storage/cdn/whi...
# 8   https://static.coinpaprika.com/storage/cdn/whi...
# 9   https://static.coinpaprika.com/storage/cdn/whi...
# 10  https://static.coinpaprika.com/storage/cdn/whi...
# 11  https://static.coinpaprika.com/storage/cdn/whi...
# 12  https://static.coinpaprika.com/storage/cdn/whi...
# 13  https://static.coinpaprika.com/storage/cdn/whi...
# 14  https://static.coinpaprika.com/storage/cdn/whi...
# 15  https://static.coinpaprika.com/storage/cdn/whi...
# 16  https://static.coinpaprika.com/storage/cdn/whi...
# 17  https://static.coinpaprika.com/storage/cdn/whi...
# 18  https://static.coinpaprika.com/storage/cdn/whi...
# 19  https://static.coinpaprika.com/storage/cdn/whi...
# 20  https://static.coinpaprika.com/storage/cdn/whi...
# 21  https://static.coinpaprika.com/storage/cdn/whi...
# 22  https://static.coinpaprika.com/storage/cdn/whi...
# 23  https://static.coinpaprika.com/storage/cdn/whi...
# 24  https://static.coinpaprika.com/storage/cdn/whi...
# 25  https://static.coinpaprika.com/storage/cdn/whi...
# 26  https://static.coinpaprika.com/storage/cdn/whi...
# 27  https://static.coinpaprika.com/storage/cdn/whi...
#
#                                  whitepaper.thumbnail            tags.id  \
# 0   https://static.coinpaprika.com/storage/cdn/whi...             segwit
# 1   https://static.coinpaprika.com/storage/cdn/whi...             segwit
# 2   https://static.coinpaprika.com/storage/cdn/whi...             segwit
# 3   https://static.coinpaprika.com/storage/cdn/whi...             segwit
# 4   https://static.coinpaprika.com/storage/cdn/whi...     cryptocurrency
# 5   https://static.coinpaprika.com/storage/cdn/whi...     cryptocurrency
# 6   https://static.coinpaprika.com/storage/cdn/whi...     cryptocurrency
# 7   https://static.coinpaprika.com/storage/cdn/whi...     cryptocurrency
# 8   https://static.coinpaprika.com/storage/cdn/whi...      proof-of-work
# 9   https://static.coinpaprika.com/storage/cdn/whi...      proof-of-work
# 10  https://static.coinpaprika.com/storage/cdn/whi...      proof-of-work
# 11  https://static.coinpaprika.com/storage/cdn/whi...      proof-of-work
# 12  https://static.coinpaprika.com/storage/cdn/whi...           payments
# 13  https://static.coinpaprika.com/storage/cdn/whi...           payments
# 14  https://static.coinpaprika.com/storage/cdn/whi...           payments
# 15  https://static.coinpaprika.com/storage/cdn/whi...           payments
# 16  https://static.coinpaprika.com/storage/cdn/whi...             sha256
# 17  https://static.coinpaprika.com/storage/cdn/whi...             sha256
# 18  https://static.coinpaprika.com/storage/cdn/whi...             sha256
# 19  https://static.coinpaprika.com/storage/cdn/whi...             sha256
# 20  https://static.coinpaprika.com/storage/cdn/whi...             mining
# 21  https://static.coinpaprika.com/storage/cdn/whi...             mining
# 22  https://static.coinpaprika.com/storage/cdn/whi...             mining
# 23  https://static.coinpaprika.com/storage/cdn/whi...             mining
# 24  https://static.coinpaprika.com/storage/cdn/whi...  lightning-network
# 25  https://static.coinpaprika.com/storage/cdn/whi...  lightning-network
# 26  https://static.coinpaprika.com/storage/cdn/whi...  lightning-network
# 27  https://static.coinpaprika.com/storage/cdn/whi...  lightning-network
#
#             tags.name tags.coin_counter tags.ico_counter  \
# 0              Segwit                10                0
# 1              Segwit                10                0
# 2              Segwit                10                0
# 3              Segwit                10                0
# 4      Cryptocurrency               856               40
# 5      Cryptocurrency               856               40
# 6      Cryptocurrency               856               40
# 7      Cryptocurrency               856               40
# 8       Proof Of Work               424               14
# 9       Proof Of Work               424               14
# 10      Proof Of Work               424               14
# 11      Proof Of Work               424               14
# 12           Payments               171               39
# 13           Payments               171               39
# 14           Payments               171               39
# 15           Payments               171               39
# 16             Sha256                42                1
# 17             Sha256                42                1
# 18             Sha256                42                1
# 19             Sha256                42                1
# 20             Mining               275               18
# 21             Mining               275               18
# 22             Mining               275               18
# 23             Mining               275               18
# 24  Lightning Network                 6                0
# 25  Lightning Network                 6                0
# 26  Lightning Network                 6                0
# 27  Lightning Network                 6                0
#
#                     team.id                 team.name         team.position
# 0          satoshi-nakamoto          Satoshi Nakamoto               Founder
# 1   wladimir-j-van-der-laan  Wladimir J. van der Laan  Blockchain Developer
# 2            jonas-schnelli            Jonas Schnelli  Blockchain Developer
# 3               marco-falke               Marco Falke  Blockchain Developer
# 4          satoshi-nakamoto          Satoshi Nakamoto               Founder
# 5   wladimir-j-van-der-laan  Wladimir J. van der Laan  Blockchain Developer
# 6            jonas-schnelli            Jonas Schnelli  Blockchain Developer
# 7               marco-falke               Marco Falke  Blockchain Developer
# 8          satoshi-nakamoto          Satoshi Nakamoto               Founder
# 9   wladimir-j-van-der-laan  Wladimir J. van der Laan  Blockchain Developer
# 10           jonas-schnelli            Jonas Schnelli  Blockchain Developer
# 11              marco-falke               Marco Falke  Blockchain Developer
# 12         satoshi-nakamoto          Satoshi Nakamoto               Founder
# 13  wladimir-j-van-der-laan  Wladimir J. van der Laan  Blockchain Developer
# 14           jonas-schnelli            Jonas Schnelli  Blockchain Developer
# 15              marco-falke               Marco Falke  Blockchain Developer
# 16         satoshi-nakamoto          Satoshi Nakamoto               Founder
# 17  wladimir-j-van-der-laan  Wladimir J. van der Laan  Blockchain Developer
# 18           jonas-schnelli            Jonas Schnelli  Blockchain Developer
# 19              marco-falke               Marco Falke  Blockchain Developer
# 20         satoshi-nakamoto          Satoshi Nakamoto               Founder
# 21  wladimir-j-van-der-laan  Wladimir J. van der Laan  Blockchain Developer
# 22           jonas-schnelli            Jonas Schnelli  Blockchain Developer
# 23              marco-falke               Marco Falke  Blockchain Developer
# 24         satoshi-nakamoto          Satoshi Nakamoto               Founder
# 25  wladimir-j-van-der-laan  Wladimir J. van der Laan  Blockchain Developer
# 26           jonas-schnelli            Jonas Schnelli  Blockchain Developer
# 27              marco-falke               Marco Falke  Blockchain Developer
#
# [28 rows x 34 columns]
