# %% [markdown]
# import necessary libraries

# %%
import requests
import pandas as pd
import json

# %% [markdown]
# assign api to variable

# %%
url = "https://api.teleport.org/api/urban_areas/teleport%3A9q8yy/scores/"

# %% [markdown]
# check error response for api

# %%
data = requests.get(url).json()

# %%
data
# Out:
# {'_links': {'curies': [{'href': 'https://developers.teleport.org/api/resources/Location/#!/relations/{rel}/',
#     'name': 'location',
#     'templated': True},
#    {'href': 'https://developers.teleport.org/api/resources/City/#!/relations/{rel}/',
#     'name': 'city',
#     'templated': True},
#    {'href': 'https://developers.teleport.org/api/resources/UrbanArea/#!/relations/{rel}/',
#     'name': 'ua',
#     'templated': True},
#    {'href': 'https://developers.teleport.org/api/resources/Country/#!/relations/{rel}/',
#     'name': 'country',
#     'templated': True},
#    {'href': 'https://developers.teleport.org/api/resources/Admin1Division/#!/relations/{rel}/',
#     'name': 'a1',
#     'templated': True},
#    {'href': 'https://developers.teleport.org/api/resources/Timezone/#!/relations/{rel}/',
#     'name': 'tz',
#     'templated': True}],
#   'self': {'href': 'https://api.teleport.org/api/urban_areas/slug:san-francisco-bay-area/scores/'}},
#  'categories': [{'color': '#f3c32c',
#    'name': 'Housing',
#    'score_out_of_10': 1.0},
#   {'color': '#f3d630', 'name': 'Cost of Living', 'score_out_of_10': 2.618},
#   {'color': '#f4eb33', 'name': 'Startups', 'score_out_of_10': 10.0},
#   {'color': '#d2ed31', 'name': 'Venture Capital', 'score_out_of_10': 10.0},
#   {'color': '#7adc29',
#    'name': 'Travel Connectivity',
#    'score_out_of_10': 3.6545000000000005},
#   {'color': '#36cc24',
#    'name': 'Commute',
#    'score_out_of_10': 4.687250000000001},
#   {'color': '#19ad51', 'name': 'Business Freedom', 'score_out_of_10': 8.671},
#   {'color': '#0d6999',
#    'name': 'Safety',
#    'score_out_of_10': 5.7155000000000005},
#   {'color': '#051fa5', 'name': 'Healthcare', 'score_out_of_10': 8.748},
#   {'color': '#150e78', 'name': 'Education', 'score_out_of_10': 8.6245},
#   {'color': '#3d14a4',
#    'name': 'Environmental Quality',
#    'score_out_of_10': 6.4815000000000005},
#   {'color': '#5c14a1', 'name': 'Economy', 'score_out_of_10': 6.5145},
#   {'color': '#88149f', 'name': 'Taxation', 'score_out_of_10': 4.488},
#   {'color': '#b9117d',
#    'name': 'Internet Access',
#    'score_out_of_10': 5.605500000000001},
#   {'color': '#d10d54', 'name': 'Leisure & Culture', 'score_out_of_10': 9.407},
#   {'color': '#e70c26',
#    'name': 'Tolerance',
#    'score_out_of_10': 8.012500000000001},
#   {'color': '#f1351b', 'name': 'Outdoors', 'score_out_of_10': 7.014}],
#  'summary': '<p>San Francisco Bay Area, California, is among the leading cities with a <b>higher number of accelerators or available funding</b>.\n\n    \n        According to our city rankings, this is a good place to live with high ratings in <b>startups</b>, <b>business freedom</b> and <b>healthcare</b>.\n    \n\n    \n</p>\n\n\n    <p>San Francisco Bay Area is one of the top ten city matches for 6.9% of Teleport users.</p>\n',
#  'teleport_city_score': 65.53635135135136}

# %%
data=pd.json_normalize(data)
data
# Out:
#                                           categories  \
# 0  [{'color': '#f3c32c', 'name': 'Housing', 'scor...
#
#                                              summary  teleport_city_score  \
# 0  <p>San Francisco Bay Area, California, is amon...            65.536351
#
#                                        _links.curies  \
# 0  [{'href': 'https://developers.teleport.org/api...
#
#                                     _links.self.href
# 0  https://api.teleport.org/api/urban_areas/slug:...

# %%
pd.json_normalize(
    data, 
    record_path =["categories","_links.curies"], 
    meta=['teleport_city_score'],
    errors='ignore'
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-ef9b3608de18> in <module>
# ----> 1 pd.json_normalize(
#       2     data,
#       3     record_path =["categories","_links.curies"],
#       4     meta=['teleport_city_score'],
#       5     errors='ignore'
#
# ~\anaconda3\envs\test\lib\site-packages\pandas\io\json\_normalize.py in _json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     334                 records.extend(recs)
#     335
# --> 336     _recursive_extract(data, record_path, {}, level=0)
#     337
#     338     result = DataFrame(records)
#
# ~\anaconda3\envs\test\lib\site-packages\pandas\io\json\_normalize.py in _recursive_extract(data, path, seen_meta, level)
#     302                 for val, key in zip(_meta, meta_keys):
#     303                     if level + 1 == len(val):
# --> 304                         seen_meta[key] = _pull_field(obj, val[-1])
#     305
#     306                 _recursive_extract(obj[path[0]], path[1:], seen_meta, level=level + 1)
#
# ~\anaconda3\envs\test\lib\site-packages\pandas\io\json\_normalize.py in _pull_field(js, spec)
#     237                 result = result[field]
#     238         else:
# --> 239             result = result[spec]
#     240         return result
#     241
#
# TypeError: string indices must be integers

# %%
d = data.explode("categories", ignore_index=True)
d = d.explode("_links.curies", ignore_index=True)
d
# Out:
#                                             categories  \
# 0    {'color': '#f3c32c', 'name': 'Housing', 'score...
# 1    {'color': '#f3c32c', 'name': 'Housing', 'score...
# 2    {'color': '#f3c32c', 'name': 'Housing', 'score...
# 3    {'color': '#f3c32c', 'name': 'Housing', 'score...
# 4    {'color': '#f3c32c', 'name': 'Housing', 'score...
# ..                                                 ...
# 97   {'color': '#f1351b', 'name': 'Outdoors', 'scor...
# 98   {'color': '#f1351b', 'name': 'Outdoors', 'scor...
# 99   {'color': '#f1351b', 'name': 'Outdoors', 'scor...
# 100  {'color': '#f1351b', 'name': 'Outdoors', 'scor...
# 101  {'color': '#f1351b', 'name': 'Outdoors', 'scor...
#
#                                                summary  teleport_city_score  \
# 0    <p>San Francisco Bay Area, California, is amon...            65.536351
# 1    <p>San Francisco Bay Area, California, is amon...            65.536351
# 2    <p>San Francisco Bay Area, California, is amon...            65.536351
# 3    <p>San Francisco Bay Area, California, is amon...            65.536351
# 4    <p>San Francisco Bay Area, California, is amon...            65.536351
# ..                                                 ...                  ...
# 97   <p>San Francisco Bay Area, California, is amon...            65.536351
# 98   <p>San Francisco Bay Area, California, is amon...            65.536351
# 99   <p>San Francisco Bay Area, California, is amon...            65.536351
# 100  <p>San Francisco Bay Area, California, is amon...            65.536351
# 101  <p>San Francisco Bay Area, California, is amon...            65.536351
#
#                                          _links.curies  \
# 0    {'href': 'https://developers.teleport.org/api/...
# 1    {'href': 'https://developers.teleport.org/api/...
# 2    {'href': 'https://developers.teleport.org/api/...
# 3    {'href': 'https://developers.teleport.org/api/...
# 4    {'href': 'https://developers.teleport.org/api/...
# ..                                                 ...
# 97   {'href': 'https://developers.teleport.org/api/...
# 98   {'href': 'https://developers.teleport.org/api/...
# 99   {'href': 'https://developers.teleport.org/api/...
# 100  {'href': 'https://developers.teleport.org/api/...
# 101  {'href': 'https://developers.teleport.org/api/...
#
#                                       _links.self.href
# 0    https://api.teleport.org/api/urban_areas/slug:...
# 1    https://api.teleport.org/api/urban_areas/slug:...
# 2    https://api.teleport.org/api/urban_areas/slug:...
# 3    https://api.teleport.org/api/urban_areas/slug:...
# 4    https://api.teleport.org/api/urban_areas/slug:...
# ..                                                 ...
# 97   https://api.teleport.org/api/urban_areas/slug:...
# 98   https://api.teleport.org/api/urban_areas/slug:...
# 99   https://api.teleport.org/api/urban_areas/slug:...
# 100  https://api.teleport.org/api/urban_areas/slug:...
# 101  https://api.teleport.org/api/urban_areas/slug:...
#
# [102 rows x 5 columns]

# %%
d=pd.json_normalize(json.loads(d.to_json(orient="records")))
d
# Out:
#                                                summary  teleport_city_score  \
# 0    <p>San Francisco Bay Area, California, is amon...            65.536351
# 1    <p>San Francisco Bay Area, California, is amon...            65.536351
# 2    <p>San Francisco Bay Area, California, is amon...            65.536351
# 3    <p>San Francisco Bay Area, California, is amon...            65.536351
# 4    <p>San Francisco Bay Area, California, is amon...            65.536351
# ..                                                 ...                  ...
# 97   <p>San Francisco Bay Area, California, is amon...            65.536351
# 98   <p>San Francisco Bay Area, California, is amon...            65.536351
# 99   <p>San Francisco Bay Area, California, is amon...            65.536351
# 100  <p>San Francisco Bay Area, California, is amon...            65.536351
# 101  <p>San Francisco Bay Area, California, is amon...            65.536351
#
#                                       _links.self.href categories.color  \
# 0    https://api.teleport.org/api/urban_areas/slug:...          #f3c32c
# 1    https://api.teleport.org/api/urban_areas/slug:...          #f3c32c
# 2    https://api.teleport.org/api/urban_areas/slug:...          #f3c32c
# 3    https://api.teleport.org/api/urban_areas/slug:...          #f3c32c
# 4    https://api.teleport.org/api/urban_areas/slug:...          #f3c32c
# ..                                                 ...              ...
# 97   https://api.teleport.org/api/urban_areas/slug:...          #f1351b
# 98   https://api.teleport.org/api/urban_areas/slug:...          #f1351b
# 99   https://api.teleport.org/api/urban_areas/slug:...          #f1351b
# 100  https://api.teleport.org/api/urban_areas/slug:...          #f1351b
# 101  https://api.teleport.org/api/urban_areas/slug:...          #f1351b
#
#     categories.name  categories.score_out_of_10  \
# 0           Housing                       1.000
# 1           Housing                       1.000
# 2           Housing                       1.000
# 3           Housing                       1.000
# 4           Housing                       1.000
# ..              ...                         ...
# 97         Outdoors                       7.014
# 98         Outdoors                       7.014
# 99         Outdoors                       7.014
# 100        Outdoors                       7.014
# 101        Outdoors                       7.014
#
#                                     _links.curies.href _links.curies.name  \
# 0    https://developers.teleport.org/api/resources/...           location
# 1    https://developers.teleport.org/api/resources/...               city
# 2    https://developers.teleport.org/api/resources/...                 ua
# 3    https://developers.teleport.org/api/resources/...            country
# 4    https://developers.teleport.org/api/resources/...                 a1
# ..                                                 ...                ...
# 97   https://developers.teleport.org/api/resources/...               city
# 98   https://developers.teleport.org/api/resources/...                 ua
# 99   https://developers.teleport.org/api/resources/...            country
# 100  https://developers.teleport.org/api/resources/...                 a1
# 101  https://developers.teleport.org/api/resources/...                 tz
#
#      _links.curies.templated
# 0                       True
# 1                       True
# 2                       True
# 3                       True
# 4                       True
# ..                       ...
# 97                      True
# 98                      True
# 99                      True
# 100                     True
# 101                     True
#
# [102 rows x 9 columns]
